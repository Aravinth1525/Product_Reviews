# %%
import nltk
from nltk.corpus import stopwords
from nltk.sentiment import SentimentIntensityAnalyzer
from wordcloud import WordCloud
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
name="ARAVINTH R"
regno="19MIC0053"

# %%
def preprocess_text(text):
    words = nltk.word_tokenize(text.lower())
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word.isalnum() and word not in stop_words]
    return words

# %%
def read_text_file(file_path):
    with open(file_path, 'r',encoding="utf-8") as file:
        text = file.read()
    return text

# %%
def create_word_cloud(words):
    word_cloud = WordCloud(width=800, height=400, background_color='white').generate(' '.join(words))
    plt.figure(figsize=(10, 5))
    plt.imshow(word_cloud, interpolation='bilinear')
    plt.axis('off')
    plt.show()

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/aravinth/nltk_data...
# True

# %%
def analyze_text(file_path):

    text = read_text_file(file_path)

    words = preprocess_text(text)
    sia = SentimentIntensityAnalyzer()
    for i in range(100):
      words.append(str(name))
      words.append(str(regno))
    create_word_cloud(words)
    positive_words = [word for word in words if sia.polarity_scores(word)['compound'] >= 0.5]
    print(len(positive_words))
    for i in range(20):
      positive_words.append(str(name))
      positive_words.append(str(regno))
    create_word_cloud(positive_words)

    negative_words = [word for word in words if sia.polarity_scores(word)['compound'] <= -0.5]
    for i in range(5):
      negative_words.append(str(name))
      negative_words.append(str(regno))
    print(len(negative_words))
    create_word_cloud(negative_words)
file_path = 'reviews.txt'
analyze_text(file_path)
# Out:
# 440
# 82
